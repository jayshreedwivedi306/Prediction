# %% [markdown]
# # Snack Prediction

# %% [markdown]
# # Project Goal

# %% [raw]
# Analyze snack from company name  to identify expiring products and understand profit–loss trends for better decision-making.

# %% [markdown]
# # Load Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Dataset

# %%
df_snacks= pd.read_csv(r"C:\Users\dshak\Downloads\Snacks_data.csv")
df_snacks.shape
# Out:
# (100, 7)

# %%
#show data

df_snacks
# Out:
#    Snack Name Company Name  Price    MFG Date    EXP Date  Profit Year  \
# 0     Namkeen       Balaji    139  2023-01-22  2023-08-11         2026
# 1     Noodles       Balaji    161  2023-07-24  2023-12-07         2023
# 2       Candy          ITC    172  2023-06-11  2024-04-20         2026
# 3       Chips        Parle     81  2023-03-07  2023-07-16         2026
# 4       Candy        Parle    120  2023-01-06  2023-06-14         2024
# ..        ...          ...    ...         ...         ...          ...
# 95  Chocolate        Parle     76  2023-06-21  2023-12-16         2026
# 96      Candy       Balaji    148  2023-08-27  2024-03-05         2023
# 97   Biscuits        Parle    109  2023-05-18  2024-01-27         2024
# 98  Chocolate       Balaji    150  2023-11-20  2024-08-02         2024
# 99    Cookies       Nestle     32  2023-05-16  2023-12-10         2026
#
#     Loss year
# 0        2018
# 1        2021
# 2        2016
# 3        2016
# 4        2015
# ..        ...
# ...

# %%
df_snacks.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Snack Name    100 non-null    str
#  1   Company Name  100 non-null    str
#  2   Price         100 non-null    int64
#  3   MFG Date      100 non-null    str
#  4   EXP Date      100 non-null    str
#  5   Profit Year   100 non-null    int64
#  6   Loss year     100 non-null    int64
# dtypes: int64(3), str(4)
# memory usage: 5.6 KB

# %%
sns.displot(df_snacks['Price'])

# %%
df_snacks['Company Name'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company Name'>

# %%
sns.barplot(x=df_snacks['Company Name'], y=df_snacks['Price'])
plt.xticks(rotation='horizontal')
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'Balaji'),
#   Text(1, 0, 'ITC'),
#   Text(2, 0, 'Parle'),
#   Text(3, 0, 'Britannia'),
#   Text(4, 0, 'PepsiCo'),
#   Text(5, 0, 'Nestle'),
#   Text(6, 0, 'Haldiram'),
#   Text(7, 0, 'Kurkure')])

# %%
sns.histplot(x=df_snacks['Company Name'], y=df_snacks['Profit Year'])
plt.xticks(rotation='vertical')
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'Balaji'),
#   Text(1, 0, 'ITC'),
#   Text(2, 0, 'Parle'),
#   Text(3, 0, 'Britannia'),
#   Text(4, 0, 'PepsiCo'),
#   Text(5, 0, 'Nestle'),
#   Text(6, 0, 'Haldiram'),
#   Text(7, 0, 'Kurkure')])

# %%
df_snacks['Snack Name'].value_counts().plot(kind='pie')
# Out:
# <Axes: >

# %%
sns.scatterplot(x=df_snacks['Snack Name'],y=df_snacks['Price'])
# Out:
# <Axes: xlabel='Snack Name', ylabel='Price'>

# %%
df_snacks['EXP Date']=df_snacks['Snack Name'].apply(lambda x:1 if 'EXP Date' in x else 0)

# %%
df_snacks.head(20)
# Out:
#    Snack Name Company Name  Price    MFG Date  EXP Date  Profit Year  \
# 0     Namkeen       Balaji    139  2023-01-22         0         2026
# 1     Noodles       Balaji    161  2023-07-24         0         2023
# 2       Candy          ITC    172  2023-06-11         0         2026
# 3       Chips        Parle     81  2023-03-07         0         2026
# 4       Candy        Parle    120  2023-01-06         0         2024
# 5     Namkeen    Britannia     35  2023-12-23         0         2024
# 6     Namkeen      PepsiCo    175  2023-11-13         0         2024
# 7       Candy       Nestle    129  2023-06-10         0         2024
# 8       Chips       Balaji     20  2023-09-19         0         2025
# 9     Noodles       Nestle    175  2023-04-14         0         2023
# 10    Noodles    Britannia    181  2023-11-08         0         2026
# 11    Cookies       Nestle     50  2023-09-21         0         2023
# 12      Candy       Balaji    172  2023-01-11         0         2025
# ...

# %%
sns.barplot(x=df_snacks['EXP Date'], y =df_snacks ['Price'])
# Out:
# <Axes: xlabel='EXP Date', ylabel='Price'>

# %%
df_snacks['EXP Date'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='EXP Date'>

# %%
sns.lineplot(x=df_snacks['MFG Date'],y=df_snacks['Price'])
# Out:
# <Axes: xlabel='MFG Date', ylabel='Price'>

# %%
def fetch_Company_Name(text):
    if text=="Nestle" or text=="Balaji":
       return text
    else:
       if text.split()[0]=='Nestle':
             return ' other Company Name'
       else:
           return 'Nestle'

# %%
df_snacks['Snack Name']=df_snacks['Snack Name'].apply(fetch_Company_Name)

# %%
df_snacks.head(20)
# Out:
#    Snack Name Company Name  Price    MFG Date  EXP Date  Profit Year  \
# 0      Nestle       Balaji    139  2023-01-22         0         2026
# 1      Nestle       Balaji    161  2023-07-24         0         2023
# 2      Nestle          ITC    172  2023-06-11         0         2026
# 3      Nestle        Parle     81  2023-03-07         0         2026
# 4      Nestle        Parle    120  2023-01-06         0         2024
# 5      Nestle    Britannia     35  2023-12-23         0         2024
# 6      Nestle      PepsiCo    175  2023-11-13         0         2024
# 7      Nestle       Nestle    129  2023-06-10         0         2024
# 8      Nestle       Balaji     20  2023-09-19         0         2025
# 9      Nestle       Nestle    175  2023-04-14         0         2023
# 10     Nestle    Britannia    181  2023-11-08         0         2026
# 11     Nestle       Nestle     50  2023-09-21         0         2023
# 12     Nestle       Balaji    172  2023-01-11         0         2025
# ...

# %%
df_snacks['MFG Date'].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='MFG Date'>
